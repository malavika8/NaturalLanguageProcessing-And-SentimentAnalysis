# %% [markdown]
# # Using tweepy's search API

# %%
import tweepy
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
#from my developer account app
api_key = "DiJDNAjwROn5vaUl4g7Mvjxd0"
api_secret = "CMN6xWRtoDhiTO9HdN2jyIvT9Pul4I5dFsmX8ge6ETBZkGrZx0"
access_token = "1626161-DTJRUNpOa5Sk6ZICYvvPBZtUFYwxbwB5p0DnwAdbrm"
access_secret = "l6rszj9OvQdRHCOccSesz5YOG4Oq6slrmTdFH7zJizNYj"

# %%
#get the tweets using the search API

auth = tweepy.OAuthHandler(api_key, api_secret)
#auth.set_access_token(access_token, access_secret) I read it might be better without access tokens

query = "bitcoincash bch -filter:retweets"
max_tweets = 10000
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
bitcoincashsearch = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]
len(bitcoincashsearch)
# Out:
# 770

# %%
#grab a subset of the columns
justthegoodstuff = [[tweet.created_at, tweet.text, tweet.retweet_count, tweet.favorite_count, tweet.user.screen_name, tweet.user.location] for tweet in bitcoincashsearch]

# %%
justthegoodstuff
# Out:
# [[datetime.datetime(2020, 4, 7, 19, 22, 38),
#   'Les mineurs de Bitcoin Cash changent de camp avant le halving de mercredi https://t.co/bwSsDsfBux \n\n#BCH #BitcoinCash #Minage #BTC #Halving',
#   0,
#   0,
#   'cryptonews_FR',
#   'Montréal, Québec'],
#  [datetime.datetime(2020, 4, 7, 19, 10, 8),
#   '#BitcoinCash has 105 blocks to go until halving tomorrow. @ByteTree puts the market health score at 2 out of 6, whi… https://t.co/pVaCHZBm51',
#   0,
#   2,
#   'AtlasPulse',
#   'UK'],
#  [datetime.datetime(2020, 4, 7, 19, 7, 17),
#   'This is why #BitcoinCash #BCH was created. It can’t be printed out of thin air. It is a deflationary currency inste… https://t.co/Vyyg3Yvd3p',
#   0,
#   0,
#   'scotty321',
#   'Vancouver, British Columbia'],
#  [datetime.datetime(2020, 4, 7, 19, 4, 18),
#   'BCH Current Price (USD): $ 258.07 Vol: BCH 233,852.1 Change (24h): 1.57% $BCH #Bitcoincash',
#   0,
#   0,
#   'AnalysisInChain',
#   ''],
#  [datetime.datetime(2020, 4, 7, 19, 0),
#   'BCH / USD\n$256.46    |    -0.0096%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 18, 58, 19),
#   '@HuobiGlobal @CoinMarketCal @BitcoinCash #BCH is halving',
#   0,
#   0,
#   'tamilbtc',
#   'India'],
#  [datetime.datetime(2020, 4, 7, 18, 0, 26),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.105,729.27 - DolarToday(Euro) Bsf.115,120.14 - bitcoin(BTC)$7,359.6… https://t.co/FvzRkXdsv7',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 7, 18, 0, 3),
#   'In last 24 hours, among top 10 #cryptocurrencies Bitcoin Cash (BCH) got the best % change (7.16 %) in price ,  Wher… https://t.co/KCWzVj4uaM',
#   0,
#   0,
#   'CurrencyBuzzer',
#   ''],
#  [datetime.datetime(2020, 4, 7, 18, 0),
#   'BCH / USD\n$258.95    |    -0.0065%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 17, 32, 14),
#   'Roughly one third of the total circulating Bitcoin Cash supply has never been touched #crypto #BitcoinCash #BCH https://t.co/J6BttWd5BT',
#   0,
#   0,
#   'ToshiTimes',
#   'New York, USA'],
#  [datetime.datetime(2020, 4, 7, 17, 0),
#   'BCH / USD\n$260.65    |    +0.0105%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 16, 49, 5),
#   "One-Third of Bitcoin Cash's Supply Has Never Been Touched\n \nData from CoinMetrics shows that roughly one-third of t… https://t.co/7a0mi5jc0g",
#   0,
#   0,
#   'BitcoINstagram',
#   'United States'],
#  [datetime.datetime(2020, 4, 7, 16, 43, 11),
#   "#Bitcoin /#BitcoinCash giveaway. To help with those who lost their jobs due to recent economic conditions, we're do… https://t.co/kb9ROiIP3z",
#   10,
#   8,
#   'BitcoinToilet',
#   'North Carolina, USA'],
#  [datetime.datetime(2020, 4, 7, 16, 43, 8),
#   'The #BitcoinCash #halving is expected to occur in less than 24 hours. Do you expect it to have a big impact on the… https://t.co/K2hV0p96MN',
#   0,
#   1,
#   'CoinCodex',
#   ''],
#  [datetime.datetime(2020, 4, 7, 16, 30, 1),
#   '$BCH/USD - buy on:@okcoin - sell on:@exmo_com - arbitrage:2.50%\n$BCH/BTC -  buy on:@hotbit_news - sell on:… https://t.co/CC6uNJCWVY',
#   0,
#   0,
#   'arbitragebot',
#   'Los Angeles, CA'],
#  [datetime.datetime(2020, 4, 7, 16, 28, 37),
#   'Bitcoin Cash Price Forecast: BCH/USD bulls eyeing fast return into $300 https://t.co/Xdw16izbCi #BitcoinCash… https://t.co/zbNfvc2JOv',
#   4,
#   0,
#   'FxScrypto',
#   ''],
#  [datetime.datetime(2020, 4, 7, 16, 17, 30),
#   '"Making Money Wasnt Easy ... But making more money Got Easier with the right tools" - CEO (BitcoinCash Ventures) https://t.co/p5hEMT7rME',
#   1,
#   5,
#   'BCH_Ventures',
#   'SHOP A4 IFEMELUNMA PLAZA, OKPU'],
#  [datetime.datetime(2020, 4, 7, 16, 9, 56),
#   "One-Third of Bitcoin Cash's Supply Has Never Been Touched #bitcoin #btc #bitcoincash #blockchain #bch https://t.co/MuAhPXsvyd",
#   0,
#   0,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 7, 16, 8, 48),
#   'BCH Is Halving :P nobody care #Crypto \n$bitcoincash $bch',
#   0,
#   0,
#   'farrukhm2010',
#   'Islamabad, Pakistan'],
#  [datetime.datetime(2020, 4, 7, 16, 3, 25),
#   'The #bitcoincash halving is in less than 24 hours. Some resources for following it here:\n\nhttps://t.co/3GdEYlOwv5 $BCH',
#   1,
#   0,
#   'Titan_Mining',
#   ''],
#  [datetime.datetime(2020, 4, 7, 16, 0),
#   'BCH / USD\n$257.95    |    +0.0129%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 15, 50),
#   'Permissionless unstoppable private peer-to-peer cash will be the lifeboat for freedom in the very near future.\n\n#BitcoinCash $BCH',
#   8,
#   23,
#   'CoinText',
#   'Onchain'],
#  [datetime.datetime(2020, 4, 7, 15, 49, 23),
#   'Crypto update:\n#Bitcoin 7300.21 +0.96%\n#Ether 170.12 +3.66%\n#Ripple (XRP) 0.1969 +1.7%\n#BitcoinCash 255.88 +2.05%… https://t.co/V3PRIkO2As',
#   0,
#   1,
#   'PhoenixSquawk',
#   ''],
#  [datetime.datetime(2020, 4, 7, 15, 43, 31),
#   'Welke 3 #crypto moet je deze week in de gaten houden? \n\nOntdek het hier!\n\nhttps://t.co/0f4i7YowkJ\n\n$BTC $ETH $BCH… https://t.co/PeJqHdtenG',
#   0,
#   0,
#   'CryptoCoinBit',
#   ''],
#  [datetime.datetime(2020, 4, 7, 15, 37, 42),
#   'Watch the Bitcoin Cash block reward halving live!\n\nhttps://t.co/JD84ewQ9hS\n\n#bitcoin #BitcoinCash #bch #halving #halvening',
#   0,
#   2,
#   'Coin_Dance',
#   ''],
#  [datetime.datetime(2020, 4, 7, 15, 8, 27),
#   "Ether going down. Look for support around 164-162 $USDT, if that doesn't hold we can look for support on the red su… https://t.co/XwDizH24FD",
#   0,
#   3,
#   'zabisara',
#   'Dark Side Of The Moon'],
#  [datetime.datetime(2020, 4, 7, 15, 0),
#   'BCH / USD\n$254.67    |    -0.0164%📉\n#BCHUSD #BitcoinCash',
#   1,
#   1,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 14, 15, 43),
#   '#BitcoinCash is up 5.64% on the day.\n#BCH is currently trading at $258.13 #USD.\nOn the 7 day chart, $BCH is up 17.1… https://t.co/0NrS3qqzu4',
#   0,
#   1,
#   'CryptoPolka',
#   'Earth'],
#  [datetime.datetime(2020, 4, 7, 14, 5, 4),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 83% \n▼DOWN 17%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/Y6Jq7hp0Tl",
#   0,
#   1,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 7, 14, 0),
#   'BCH / USD\n$258.92    |    +0.0027%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 13, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n15,832 #BCH (4,068,690 USD) from multiple addresses to… https://t.co/OVCrmr2AwL',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 7, 13, 38, 45),
#   'Bitcoin Cash N95 Mask\n\nWay to cash in on the pandemic $BCH crew! Not a good look. https://t.co/befLYReQI0',
#   0,
#   1,
#   '_the_archer',
#   'None of your business'],
#  [datetime.datetime(2020, 4, 7, 13, 34, 24),
#   'Attention, ça va couper ✂️ #BitcoinCash #BCH \nhttps://t.co/2lirSAja5e',
#   0,
#   0,
#   'LeJournalDuCoin',
#   'Francophonie'],
#  [datetime.datetime(2020, 4, 7, 13, 13, 3),
#   '#BitcoinCash is halving in less than 24 hours! 🔥🚀\n\n#BCHforEveryone🌏 $BCH\nhttps://t.co/HkGQFf1Z4U',
#   1,
#   11,
#   'BitcoinCashA',
#   'Global'],
#  [datetime.datetime(2020, 4, 7, 13, 0, 6),
#   'The #BitcoinCash community has an opportunity to support real decentralised development.\n\nSupporting teams such as… https://t.co/yjRmYTIJd5',
#   4,
#   12,
#   'BitcoinUnlimit',
#   'Global'],
#  [datetime.datetime(2020, 4, 7, 13, 0),
#   'BCH / USD\n$258.22    |    -0.0034%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 12, 27, 29),
#   '⌛️فردا (8 آوریل) پاداش استخراج هر 210,000 بلوک #BCH نصف خواهد شد و پاداش توکن\u200cهای آن از 12.5 به 6.25 کاهش خواهد یاف… https://t.co/OXcvuljH86',
#   0,
#   4,
#   'CryptoLand_FA',
#   ''],
#  [datetime.datetime(2020, 4, 7, 12, 19, 55),
#   '⌛️Tommorow (8 April), The #BCH block mining reward halves every 210,000 blocks, the coin reward will decrease from… https://t.co/nGRxkMKkUP',
#   0,
#   0,
#   'Cryptoland_EN',
#   ''],
#  [datetime.datetime(2020, 4, 7, 12, 19, 50),
#   '♦️@coinmetrics claims that the Halving of @BitcoinCash ( $BCH) could force the miners to surrender and enter the mo… https://t.co/FrLOTlYEUY',
#   0,
#   0,
#   'Cryptoland_EN',
#   ''],
#  [datetime.datetime(2020, 4, 7, 12, 0, 29),
#   '¿Para qué se usa #Bitcoin Cash? https://t.co/ptJbA6XLyK #criptomonedas #bch #bitcoincash',
#   0,
#   0,
#   'uFercho',
#   ''],
#  [datetime.datetime(2020, 4, 7, 12, 0, 1),
#   'BCH / USD\n$259.10    |    -0.0097%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 11, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 80% \n▼DOWN 20%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/WIowxr09TQ",
#   1,
#   1,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 7, 11, 0, 1),
#   'BCH / USD\n$261.64    |    +0.0104%📈\n#BCHUSD #BitcoinCash',
#   0,
#   1,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 10, 0, 24),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.99,043.72 - DolarToday(Euro) Bsf.107,112.81 - bitcoin(BTC)$7,383.51… https://t.co/Ki8IsdjwbR',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 7, 10, 0, 1),
#   'BCH / USD\n$258.95    |    +0.0053%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 9, 50, 6),
#   'Hoy: April 6, 2020 at 05:50AM, 1 BCH equivale a: 253.86 USD. #bitcoincash #bch #trading #mercados',
#   0,
#   0,
#   'blancomorao',
#   'Venezuela'],
#  [datetime.datetime(2020, 4, 7, 9, 45, 12),
#   '@OKEx_Zoe Is #BitcoinCash the real #Bitcoin??\n\n@Kenneth90939071 \n@QuiazonJan \n@lasercrypto20 \n@Iamnovs1121… https://t.co/pqxL4Cvcg2',
#   0,
#   2,
#   'Rogin03',
#   ''],
#  [datetime.datetime(2020, 4, 7, 9, 36, 3),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: @BITCOlNCASH Dato che tutti gli elementi sono chiaramente rialzisti, i trader potre… https://t.co/TZYbV3rRpy',
#   0,
#   0,
#   'CentralChartsIT',
#   ''],
#  [datetime.datetime(2020, 4, 7, 9, 31, 10),
#   '@HuobiGlobal @CoinMarketCal @BitcoinCash You send reward without bch Adress????? How?',
#   0,
#   1,
#   'bastien59880',
#   'Valenciennes, France'],
#  [datetime.datetime(2020, 4, 7, 9, 30, 14),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: Dato che tutti gli elementi sono chiaramente rialzisti, i trader potrebbero tradare… https://t.co/hJHqz4jHRM',
#   0,
#   0,
#   'Romia_IA',
#   ''],
#  [datetime.datetime(2020, 4, 7, 9, 27, 35),
#   '#BTC = $7,373.59\n#ETH = $173.81\n#XRP = $0.198994\n#BCH = $258.08\n\nLatest prices of different #cryptocurrencies\nFollo… https://t.co/4AiVEU0wsy',
#   0,
#   0,
#   'nioc_exchange',
#   'Estonia'],
#  [datetime.datetime(2020, 4, 7, 9, 23, 38),
#   '@HuobiGlobal @CoinMarketCal @BitcoinCash #bch halving........ And after??',
#   0,
#   1,
#   'bastien59880',
#   'Valenciennes, France'],
#  [datetime.datetime(2020, 4, 7, 9, 0, 32),
#   '2020/04/07 18:00:32\r[ bitFlyer ] \rビットコイン[BTC/JPY]：802,607円\rイーサリアム[ETH/JPY]：18,885円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.327円… https://t.co/Ci0gQdR5Za',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 7, 9, 0),
#   'BCH / USD\n$257.58    |    -0.0033%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 8, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n28,065 #BCH (7,212,330 USD) from unknow wallet to unkn… https://t.co/0owQWR3ihO',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 7, 8, 0),
#   'BCH / USD\n$258.42    |    +0.0114%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 7, 40, 23),
#   '@HuobiGlobal @CoinMarketCal @BitcoinCash #BCH is halving get ready!🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥👀',
#   1,
#   2,
#   'HuobiFutures',
#   'Bali, Indonesia'],
#  [datetime.datetime(2020, 4, 7, 7, 32, 33),
#   'Our #daily update on #Cryptocurrency #Market \n\n#Blockchain #Innovation #Futureofmoney #Stablecoin #Bitcoin #BTC… https://t.co/UpQUCHuJv8',
#   0,
#   0,
#   'ceuzcoin',
#   ''],
#  [datetime.datetime(2020, 4, 7, 7, 31, 53),
#   'Live Market Update from the CMC dealing desk - Crypto:\n#Bitcoin  7339.7 1.53%\n#Ethereum  172.88 5.38%\n#BitcoinCash… https://t.co/DxdbvxL612',
#   1,
#   3,
#   'CMCMarkets',
#   'Content is not advice'],
#  [datetime.datetime(2020, 4, 7, 7, 26, 10),
#   '1 days 2 hours 9 minutes 54 seconds left for Bitcoin Cash guys. \n#BitcoinCash #BitcoinCashHalving #BCHHalving #BCH… https://t.co/Ur3U12yP76',
#   0,
#   0,
#   'LibertarianBee',
#   ''],
#  [datetime.datetime(2020, 4, 7, 7, 8, 5),
#   'https://t.co/xTD1ePqJ0Q\n\n#blockchain #cryptocurrency #crypto #bitcoin #btc #ethereum #bitcoincash #bch #litecoin… https://t.co/rCIDlBYXQN',
#   0,
#   0,
#   'unknownstrengar',
#   'Colombo'],
#  [datetime.datetime(2020, 4, 7, 7, 6, 22),
#   '@cryptocom https://t.co/HeWQRX9ZEh Exchange users to enjoy up to 0.75% p.a. on BCH deposited to and held in the Exc… https://t.co/eticQn67Gc',
#   1,
#   2,
#   'Devsss7',
#   'world'],
#  [datetime.datetime(2020, 4, 7, 7, 5, 26),
#   'https://t.co/HeWQRX9ZEh Exchange users to enjoy up to 0.75% p.a. on BCH deposited to and held in the Exchange… https://t.co/EeYNgnlhHc',
#   2,
#   4,
#   'Devsss7',
#   'world'],
#  [datetime.datetime(2020, 4, 7, 7, 4, 45),
#   '@cryptocom #CRO #BCH #BitcoinCash\n#3for3 \n#TimeForPlanB',
#   0,
#   1,
#   'hiboat2',
#   'Abuja, Nigeria'],
#  [datetime.datetime(2020, 4, 7, 7, 2, 26),
#   '@cryptocom #3for3 \n#CRO #BCH #BitcoinCash',
#   0,
#   0,
#   'scarlet3e',
#   'Pennsylvania, USA'],
#  [datetime.datetime(2020, 4, 7, 7, 1, 50),
#   '@cryptocom #CRO #BCH #BitcoinCash',
#   0,
#   1,
#   'malditahon101',
#   'Earth'],
#  [datetime.datetime(2020, 4, 7, 7, 1, 7),
#   '$BCH is now on https://t.co/vCNztABJoG Soft Staking! Earn daily interest rate paid in #BCH on… https://t.co/rFuS2t45yp',
#   174,
#   368,
#   'cryptocom',
#   ''],
#  [datetime.datetime(2020, 4, 7, 7, 0),
#   'BCH / USD\n$255.51    |    -0.0004%📉\n#BCHUSD #BitcoinCash',
#   0,
#   1,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 6, 44, 5),
#   '@FredieStair @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp… https://t.co/nKWN3ZT9lz',
#   0,
#   0,
#   'dlss',
#   'Belgium'],
#  [datetime.datetime(2020, 4, 7, 6, 19, 14),
#   'https://t.co/bFGR9mVCuOのレイオフ報道、ロジャー・バー氏は「FUD」と否定 ｜ 仮想通貨BCHの半減期にもコメント \n\n#仮想通貨 #BitcoinCash $BCH \n\nhttps://t.co/odl3eWFJYc',
#   3,
#   12,
#   'JpCointelegraph',
#   '日本'],
#  [datetime.datetime(2020, 4, 7, 6, 17, 19),
#   'Bitcoin Cash (BCH / USD) se négocie à 253. Les cotations de crypto-monnaie se négocient au-dessus de la moyenne mob… https://t.co/RBiBpigdni',
#   0,
#   0,
#   'CoignardDavid',
#   ''],
#  [datetime.datetime(2020, 4, 7, 6, 0),
#   'BCH / USD\n$255.60    |    +0.0055%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 5, 50, 24),
#   '😱🤔\n#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/HlRmU14zcF',
#   0,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 7, 5, 44, 58),
#   '#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/tNv0U1q2F6',
#   0,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 7, 5, 5, 8),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 67% \n▼DOWN 33%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/ZGix69xpBO",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 7, 5, 0),
#   'BCH / USD\n$254.20    |    -0.0085%📉\n#BCHUSD #BitcoinCash',
#   0,
#   1,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 4, 32, 1),
#   'https://t.co/0vhiXlQv7n\nCrypto update:\n#Bitcoin 7300.21 +0.96%\n#Ether 170.12 +3.66%\n#Ripple (XRP) 0.1969 +1.7%… https://t.co/h2g5pJa2tM',
#   8,
#   7,
#   'shares_aim',
#   'United Kingdom'],
#  [datetime.datetime(2020, 4, 7, 4, 0),
#   'BCH / USD\n$256.38    |    +0.0049%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 3, 42),
#   'Crypto update:\n#Bitcoin 7300.21 +0.96%\n#Ether 170.12 +3.66%\n#Ripple (XRP) 0.1969 +1.7%\n#BitcoinCash 255.88 +2.05%… https://t.co/C68YEsezHu',
#   7,
#   4,
#   'IGSquawk',
#   'Global'],
#  [datetime.datetime(2020, 4, 7, 3, 33, 21),
#   'Protect ya neck! Brand new $bch face masks and bandanas are now available for sale at https://t.co/mtXPPWifW4!… https://t.co/sPmRiNTKGR',
#   0,
#   3,
#   'Human_actionLLC',
#   'Louisville, KY'],
#  [datetime.datetime(2020, 4, 7, 3, 32, 50),
#   "Don't miss this marathon livestream during the #BitcoinCash halvening! \n\nSubscribe and turn on notifications so you… https://t.co/NJ6I28ggJW",
#   2,
#   12,
#   'BitcoinUnlimit',
#   'Global'],
#  [datetime.datetime(2020, 4, 7, 3, 0, 34),
#   '2020/04/07 12:00:34\r[ bitFlyer ] \rビットコイン[BTC/JPY]：798,000円\rイーサリアム[ETH/JPY]：18,601円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.2811円… https://t.co/2ZgkLoQbev',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 7, 3, 0),
#   'BCH / USD\n$255.13    |    -0.0072%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 2, 57, 17),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2 https://t.co/NjPc7tvKCZ',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 4, 7, 2, 56, 52),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 4, 7, 2, 54, 50),
#   'https://t.co/saX0K0wG1M\nThe Crypto Flow Intel Report for 4/7/20 now available\n \n#CFx #MachineLearning #Finance… https://t.co/OaD28DDsDv',
#   0,
#   0,
#   'KeyMajorCoin',
#   'United States'],
#  [datetime.datetime(2020, 4, 7, 2, 1, 27),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.99,043.72 - DolarToday(Euro) Bsf.107,112.81 - bitcoin(BTC)$7,346.67… https://t.co/M7buWiLhGa',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 7, 2, 0),
#   'BCH / USD\n$256.99    |    -0.0019%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 1, 56, 8),
#   "Congrats to ProtocolLevel for winning today's 0.23 BCH tournament!\n\n#blockchainpoker #bitcoin #bitcoincash #bch https://t.co/nCd9ny6Qkf",
#   1,
#   3,
#   'BlockchainPoker',
#   '/r/blockchainpoker on Reddit'],
#  [datetime.datetime(2020, 4, 7, 1, 49, 51),
#   "Fiat failing, when people rush to crypto they won't Care w which crypto they buy. They now Bitcoin but will be pres… https://t.co/0PmnJZxnrg",
#   0,
#   1,
#   'z2zbank',
#   'zaddr'],
#  [datetime.datetime(2020, 4, 7, 1, 14, 13),
#   '8000ドルまでの回復なるか\u3000ビットコイン・イーサ・XRP（リップル）・ビットコインキャッシュ・ライトコインのテクニカル分析 \n\n＃仮想通貨 #Bitcoin $BTC #Ethereum $ETH #Ripple $XRP… https://t.co/xFGZwlGQ0R',
#   5,
#   12,
#   'JpCointelegraph',
#   '日本'],
#  [datetime.datetime(2020, 4, 7, 1, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 100% \n▼DOWN 0%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/LQZxHS87xF",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 7, 1, 0, 1),
#   'BCH / USD\n$257.47    |    -0.0045%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 7, 0, 56, 32),
#   '#BCHUSD (#Coinbase ) Recommended to enter long above $194 for $280 target, now 200 DMA at $269 in the daily chart,… https://t.co/3sVd1RdFXD',
#   1,
#   6,
#   'mindandtrading',
#   'Global'],
#  [datetime.datetime(2020, 4, 7, 0, 42, 10),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n26,180 #BCH (6,728,020 USD) from unknow wallet to unkn… https://t.co/K1f5f8E5f5',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 7, 0, 1, 6),
#   'End of the days Top Gainers 📢🐂 $BTC $BSV $BCH $LTC $ $ETH $XLM $NEO $BNB $LINK $MANA $EOS \n$XRP $ZEC $XTZ $TRX $XMR… https://t.co/ar2McYJ9KF',
#   0,
#   1,
#   'OhioRy666',
#   'Cleveland, OH'],
#  [datetime.datetime(2020, 4, 7, 0, 0, 1),
#   'BCH / USD\n$258.64    |    +0.0215%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 23, 7, 47),
#   '@TheFutureofBCH @TobiasRuck @BitcoinCash @srust99 @CryptoKelso @christroutner @haydenotto_ @yhaiyang @YokooAkane… https://t.co/DOaWnTMmS3',
#   0,
#   3,
#   'georgedonnelly',
#   'Medellín, Colombia'],
#  [datetime.datetime(2020, 4, 6, 23, 0, 1),
#   'BCH / USD\n$253.20    |    -0.0013%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 22, 54, 55),
#   "Join us Wed Apr 8 from 10:30 AM UTC for a $BCH community livestream event!\n\nTogether, we'll discuss the future of… https://t.co/0dDzpEMuAb",
#   25,
#   56,
#   'TheFutureofBCH',
#   ''],
#  [datetime.datetime(2020, 4, 6, 22, 52, 31),
#   'In 2 days time the #BitcoinCash block subsidy will reduce from 12.5 BCH &gt; 6.25 BCH\n\nAs a result, the BCH inflation… https://t.co/VR7FE7EASm',
#   1,
#   13,
#   'howelzy',
#   'Wales, United Kingdom'],
#  [datetime.datetime(2020, 4, 6, 22, 0, 1),
#   'BCH / USD\n$253.53    |    +0.0120%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 21, 59, 5),
#   'Well yes when you can get a 97% discount, you do realize that #Crypto price multiples per coin do matter ...… https://t.co/cGRLZVULa5',
#   0,
#   0,
#   'CRYPTOKEN_board',
#   ''],
#  [datetime.datetime(2020, 4, 6, 21, 34),
#   '#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/uuA6qcKotj',
#   1,
#   0,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 6, 21, 33, 3),
#   '#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/vcKS3MkGx6',
#   0,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 6, 21, 9, 47),
#   'Price Analysis April 6: BTC, ETH, XRP, BCH, BSV, LTC, EOS, BNB, XTZ, LEO #altcoin #bitcoin #bitcoinhalving… https://t.co/dw6EUsFkwN',
#   0,
#   0,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 6, 21, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 100% \n▼DOWN 0%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/dmutNtdzc5",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 6, 21, 0, 8),
#   '2020/04/07 06:00:08\r[ bitFlyer ] \rビットコイン[BTC/JPY]：789,786円\rイーサリアム[ETH/JPY]：17,841円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.2734円… https://t.co/lZxtxA3Pyo',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 6, 21, 0),
#   'BCH / USD\n$250.52    |    -0.0140%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 20, 9, 7),
#   'The First daily draw of the new week has been done!Its now #BCH The winner of Sundays #LTC did not claim so it roll… https://t.co/tPy4RvSZ6u',
#   1,
#   0,
#   'FreeCryptoLotto',
#   'Bournemouth, England'],
#  [datetime.datetime(2020, 4, 6, 20, 0),
#   'BCH / USD\n$254.07    |    -0.0061%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 19, 53, 42),
#   'Kudos to @criptoph  for taking this initiative in Brazil!\n\nhttps://t.co/AJyzIL9Il0\n\n#BCH #BitcoinCash #BCHLatam',
#   2,
#   9,
#   'georgedonnelly',
#   'Medellín, Colombia'],
#  [datetime.datetime(2020, 4, 6, 19, 9, 42),
#   'Charities Are Turning to Bitcoin Amid the Global Fight Against Coronavirus #bch #bitcoincash #binance #bitcoin… https://t.co/NUR31LH3YK',
#   0,
#   1,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 6, 19, 0),
#   'BCH / USD\n$255.64    |    +0.0007%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 18, 30, 22),
#   'Which #crypto will make you the most #money before the end of the #Quarantine? Pre-Order Rates and availability for… https://t.co/zxNtvnZLM2',
#   1,
#   1,
#   'hodlershub',
#   'Hodlershub@protonmail.com'],
#  [datetime.datetime(2020, 4, 6, 18, 7, 6),
#   'BCH Current Price (USD): $ 254.79 Vol: BCH 178,090.8 Change (24h): 9.97% $BCH #Bitcoincash',
#   0,
#   0,
#   'AnalysisInChain',
#   ''],
#  [datetime.datetime(2020, 4, 6, 18, 0, 37),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.99,043.72 - DolarToday(Euro) Bsf.107,112.81 - bitcoin(BTC)$7,226.63… https://t.co/wFxtpPA8Us',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 6, 18, 0, 8),
#   'In last 24 hours, among top 10 #cryptocurrencies Bitcoin Cash (BCH) got the best % change (7.16 %) in price ,  Wher… https://t.co/Xl2N0dYaNX',
#   0,
#   0,
#   'CurrencyBuzzer',
#   ''],
#  [datetime.datetime(2020, 4, 6, 18, 0),
#   'BCH / USD\n$255.45    |    +0.0053%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 17, 49, 7),
#   '$bch / $btc: +4% value, +30% volume at #Binance (#BitcoinCash / #Bitcoin, #cryptoasset, https://t.co/lXbYi6UefJ)',
#   0,
#   0,
#   'cryptocoinradar',
#   'http://t.me/ccradarbot'],
#  [datetime.datetime(2020, 4, 6, 17, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n57,350 #BCH (13,387,100 USD) from multiple addresses t… https://t.co/hIKRDBbDCU',
#   1,
#   1,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 17, 21, 39),
#   '#BitcoinCash looking very good this morning. Pre halving bull run? We will see. \n\nBring out the whisky if we soar.… https://t.co/OE0x4IimSh',
#   2,
#   2,
#   'TheCryptoBadger',
#   'PNW'],
#  [datetime.datetime(2020, 4, 6, 17, 11, 8),
#   'What’s going to happen at the upcoming BCH Halving? Will it influence the price? Will the value of Bitcoin Cash go… https://t.co/Sdk7jnpgzJ',
#   5,
#   20,
#   'BitcoinCom',
#   'Worldwide'],
#  [datetime.datetime(2020, 4, 6, 17, 3, 51),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 4, 6, 17, 0),
#   'BCH / USD\n$254.10    |    +0.0311%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 16, 55, 33),
#   'Bitcoin Cash Price Forecast: BCH/USD bulls have decent room for fast $300 return https://t.co/rnm0AWu8xa… https://t.co/7DAxSh7CLP',
#   0,
#   1,
#   'FxScrypto',
#   ''],
#  [datetime.datetime(2020, 4, 6, 16, 39, 5),
#   '#BitcoinCash is up 6.15% for the day.\n#BCH is currently trading at $248.29 #USD.\nOn the 7 day chart, $BCH is up 13.… https://t.co/6BlxCHvPqC',
#   2,
#   2,
#   'CryptoPolka',
#   'Earth'],
#  [datetime.datetime(2020, 4, 6, 16, 33, 7),
#   '#BCH #bitcoincash to praise over 250 today possible?\nYes, as Europe and Asia are diverting to #BCH as ensurance towards #COVID19?',
#   0,
#   1,
#   'Koimaster',
#   'Belgium @ my pond :-)'],
#  [datetime.datetime(2020, 4, 6, 16, 13, 22),
#   'Our Private RNEW Faucet Channel just unlocked a new feature. Get Involved now and get some FREE #RNEW Tokens, Learn… https://t.co/KxGKqH6jjc',
#   0,
#   0,
#   'RNEW_Cash',
#   'London, UK'],
#  [datetime.datetime(2020, 4, 6, 16, 10, 38),
#   'Roger Ver Trashes Bitcoin.\u200bcom Coronavirus Layoff Claims as ‘More Bcash FUD’ #btc #bitcoin.com #bch #bitcoincash… https://t.co/NiOSON1nsC',
#   0,
#   0,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 6, 16, 5, 11),
#   'BITCOIN CASH HALVING: ONLY TWO DAYS AWAY!!\n\n$BCH #Bitcoin #Bitcoincash #BitcoinCashHaling #cryptocurrency',
#   0,
#   1,
#   'TheCryptoBadger',
#   'PNW'],
#  [datetime.datetime(2020, 4, 6, 16, 0),
#   'BCH / USD\n$246.45    |    +0.0148%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 15, 53, 9),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/JVQTsleK49',
#   0,
#   2,
#   'Danyakotov',
#   'Екатеринбург '],
#  [datetime.datetime(2020, 4, 6, 15, 33, 13),
#   "Maker, Ethereum Classic, #BitcoinCash price: BCH's future overshadows MKR and ETC's - #Altcoins #HideCryptopanic… https://t.co/WMEadXeY8S",
#   1,
#   0,
#   'PaulESamson',
#   'Bathurst, New Brunswick, Canada'],
#  [datetime.datetime(2020, 4, 6, 15, 31, 57),
#   'Now that you’re experiencing the government’s power to remove your human rights &amp; freedoms &amp; constitutional rights… https://t.co/uJ6pMxqLGw',
#   0,
#   4,
#   'scotty321',
#   'Vancouver, British Columbia'],
#  [datetime.datetime(2020, 4, 6, 15, 0),
#   'BCH / USD\n$242.85    |    -0.0068%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 53, 5),
#   '@TobiasRuck @deadalnix Tobias is going to save #BitcoinCash $BCH!\n\nThey need to take out the coinbase diversion fro… https://t.co/0R6FuqYIjH',
#   0,
#   0,
#   'CRYPTOKEN_board',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 44, 35),
#   'The White Card is now available as international Visa and MasterCard in 10 currencies.\n\nLoad BTC, ETH, BCH, XLM, BS… https://t.co/jGTv5oLcNE',
#   0,
#   0,
#   'thewcomp',
#   'Worldwide'],
#  [datetime.datetime(2020, 4, 6, 14, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n46,302 #BCH (10,808,300 USD) from multiple addresses t… https://t.co/FcSF7lCMwn',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 14, 35, 58),
#   'Thanks for putting your trust in us as well, it’s nice having you on the team .\n.\n.\n#bitcoin #ethereum #btc #eth… https://t.co/8JUxJtLBMG',
#   1,
#   1,
#   'Sarah_Wills25',
#   'Toronto Canada'],
#  [datetime.datetime(2020, 4, 6, 14, 20, 4),
#   '$BCH $BCHUSD #BITCOINCASH - Giornaliero: @BITCOlNCASH La tendenza neutra sul breve termine mostra un esaurimento de… https://t.co/bohJVC3ogy',
#   0,
#   0,
#   'CentralChartsIT',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 15, 28),
#   'Cryptocurrency Mining Rigs - https://t.co/JSWbcBdNkk - #bitcoin #blockchain #ethereum #crypto #cryptocurrency… https://t.co/EVg8CTH1qg',
#   0,
#   0,
#   'BlockchainMom',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 15, 23),
#   '$BCH $BCHUSD #BITCOINCASH - Giornaliero: La tendenza neutra sul breve termine mostra un esaurimento della tendenza… https://t.co/DgjFVf5YuK',
#   0,
#   0,
#   'Romia_IA',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 13% \n▼DOWN 88%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/q5EDT0KTNK",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 6, 14, 2, 42),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/ZDGzxJQaNs',
#   0,
#   2,
#   'dka218',
#   ''],
#  [datetime.datetime(2020, 4, 6, 14, 0),
#   'BCH / USD\n$244.51    |    +0.0018%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 13, 52, 41),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/ezfOou6NUd',
#   0,
#   1,
#   'chrispalasz',
#   'Guangdong, P.R.C.'],
#  [datetime.datetime(2020, 4, 6, 13, 42, 10),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n41,199 #BCH (9,617,020 USD) from multiple addresses to… https://t.co/XFkoGvE5qC',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 13, 26, 5),
#   '#bch to rise again. Ready... set...\n#bch #bitcoincash akming to het back in track to 350?',
#   1,
#   0,
#   'Koimaster',
#   'Belgium @ my pond :-)'],
#  [datetime.datetime(2020, 4, 6, 13, 25, 24),
#   '@girlgone_crypto Now just imagine the potential for $BCH that is trading at a 95% discount ? #bitcoincash',
#   0,
#   1,
#   'CRYPTOKEN_board',
#   ''],
#  [datetime.datetime(2020, 4, 6, 13, 10, 1),
#   '#bitcoin #btc #ether #eth #ripple #xrp #bitcoincash #bch #corretorascripto #otimismo #mercadocripto #bravenewcoin… https://t.co/OgO7RNwW4S',
#   0,
#   0,
#   'leiamoneytimes',
#   'Sao Paulo, Brazil'],
#  [datetime.datetime(2020, 4, 6, 13, 7, 25),
#   '🚨REMINDER🚨\n   #BCH, #BSV\n#Bitcoincash and #BitcoinSV halving in less than 2 days.\n\nSOURCE: https://t.co/iqkWxR2XdB https://t.co/kETgUmI06j',
#   0,
#   0,
#   'prosticas7',
#   ''],
#  [datetime.datetime(2020, 4, 6, 13, 0, 21),
#   'Learn about the latest #BitcoinCash news!\n\nWatch the weekly $BCH news series and subscribe 🛎️ https://t.co/jcoREBEWHa',
#   3,
#   13,
#   'BitcoinUnlimit',
#   'Global'],
#  [datetime.datetime(2020, 4, 6, 13, 0),
#   'BCH / USD\n$244.08    |    +0.0055%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 12, 15, 57),
#   '@ihatecodee BTC is not for payments according to its leaders. So I would suggest using the version of Bitcoin optim… https://t.co/tyNAzuF5n3',
#   0,
#   0,
#   '_MikeMalley',
#   'World'],
#  [datetime.datetime(2020, 4, 6, 12, 0, 1),
#   'BCH / USD\n$242.74    |    +0.0035%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 11, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n16,938 #BCH (3,953,930 USD) from multiple addresses to… https://t.co/ytCiOO8yus',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 11, 20, 33),
#   '#bch #bitcoincash #CBDC #christinelagarde Central Bank of South Korea Introduces Pilot Program for Testing Digital… https://t.co/B6kWn36Gpm',
#   0,
#   0,
#   '___CryptoNews',
#   'Toronto, Ontario'],
#  [datetime.datetime(2020, 4, 6, 11, 5, 4),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 17% \n▼DOWN 83%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/3mEbvWHvAz",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 6, 11, 0, 1),
#   'BCH / USD\n$241.89    |    -0.0034%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 10, 27, 54),
#   'What’s going to happen at the BCH Halvening, rumors about https://t.co/K278QCiOBK - ...#Bitcoin #BitcoinCash #BCH… https://t.co/OaJyAROM3a',
#   0,
#   1,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 6, 10, 6, 53),
#   'April 6, 2020 15:35\nTop 5 Cryptocurrencies Prices\n--------------------\nBitcoin - BTC/USD: $7,091.05 🔼 4.41%\nEthereu… https://t.co/hCNtks1ohD',
#   0,
#   0,
#   'Trade99com',
#   ''],
#  [datetime.datetime(2020, 4, 6, 10, 0, 54),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.94,120.28 - DolarToday(Euro) Bsf.101,537.90 - bitcoin(BTC)$7,123.20… https://t.co/GglpfyQVxz',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 6, 10, 0, 1),
#   'BCH / USD\n$242.72    |    +0.0126%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 9, 53, 20),
#   '$EOS $BSV $BCH \nWhat beautiful signals indicated by our algorithm today on these cryptocurrencies on our 5 minute c… https://t.co/Uwb5fDielD',
#   0,
#   1,
#   'bti_trades',
#   'TradingView'],
#  [datetime.datetime(2020, 4, 6, 9, 50, 6),
#   'Hoy: April 5, 2020 at 05:50AM, 1 BCH equivale a: 242.82 USD. #bitcoincash #bch #trading #mercados',
#   0,
#   0,
#   'blancomorao',
#   'Venezuela'],
#  [datetime.datetime(2020, 4, 6, 9, 40, 47),
#   '4 saatlik grafik,DÜK olmuş. MACD yukarı kesmesi yakın. Halving de bir hikâye... İzlemek gerek.\n\n#bch\n#bitcoincash… https://t.co/5oBqWO9ivI',
#   0,
#   0,
#   'Pandemic_7',
#   'Antalya'],
#  [datetime.datetime(2020, 4, 6, 9, 34, 22),
#   "Bitcoincash Halving'de sona yaklaşılıyor. 2 güne kadar Block 630000 diyecek. Miner'lar iş başında.. Oldukça volatil… https://t.co/w4BXLiag8Q",
#   0,
#   0,
#   'Pandemic_7',
#   'Antalya'],
#  [datetime.datetime(2020, 4, 6, 9, 24, 25),
#   '@kvetinko1 @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp… https://t.co/ambdkKjCaB',
#   0,
#   0,
#   'edin_hadzovic',
#   'Graz, Österreich'],
#  [datetime.datetime(2020, 4, 6, 9, 0, 32),
#   '2020/04/06 18:00:32\r[ bitFlyer ] \rビットコイン[BTC/JPY]：769,680円\rイーサリアム[ETH/JPY]：16,417円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.0851円… https://t.co/aqq4j7XuMJ',
#   0,
#   1,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 6, 9, 0),
#   'BCH / USD\n$239.70    |    +0.0012%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 8, 53),
#   '#BTC = $7,047.72\n#ETH = $149.63\n#XRP = $0.184217\n#BCH = $239.09\n\nLatest prices of different #cryptocurrencies\nFollo… https://t.co/Uwr2jnaI5m',
#   0,
#   1,
#   'nioc_exchange',
#   'Estonia'],
#  [datetime.datetime(2020, 4, 6, 8, 45, 9),
#   'New video: #Crypto Double Test Bottom of $100B Still Probable BUT Risky To Play:\n\nhttps://t.co/PfbTRrrJ6n… https://t.co/ndJQ0WMyBR',
#   3,
#   31,
#   'MarcDeMesel',
#   'Telegram: @MarcDeMesel'],
#  [datetime.datetime(2020, 4, 6, 8, 42, 4),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: @BITCOlNCASH BITCOIN CASH - BCH/USD is part of a very strong bullish trend. Traders… https://t.co/G4M7pcFB05',
#   0,
#   1,
#   'CentralChartsEN',
#   ''],
#  [datetime.datetime(2020, 4, 6, 8, 35, 28),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: BITCOIN CASH - BCH/USD is part of a very strong bullish trend. Traders may consider… https://t.co/SFyjPBR4MR',
#   0,
#   1,
#   'Londinia_IA',
#   ''],
#  [datetime.datetime(2020, 4, 6, 8, 0),
#   'BCH / USD\n$239.41    |    -0.0022%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 7, 53, 16),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/29l0ng32JX',
#   0,
#   0,
#   'isamalia1',
#   'Monaco'],
#  [datetime.datetime(2020, 4, 6, 7, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n4,900 #BCH (1,143,800 USD) from multiple addresses to… https://t.co/gcAo7ssmjk',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 7, 37, 12),
#   '@kvetinko1 @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp… https://t.co/0x0isoR5Ic',
#   0,
#   4,
#   'techspunk',
#   ''],
#  [datetime.datetime(2020, 4, 6, 7, 35, 12),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 4, 6, 7, 34, 55),
#   'Live Market Update from the CMC dealing desk - Crypto:\n#Bitcoin  7040.63 3.89%\n#Ethereum  149.63 5.07%\n#BitcoinCash… https://t.co/t1jeN9oV1R',
#   1,
#   1,
#   'CMCMarkets',
#   'Content is not advice'],
#  [datetime.datetime(2020, 4, 6, 7, 3, 22),
#   'Bitcoin Cash (BCH / USD) se négocie à 234. Les cotations de crypto-monnaie se négocient au-dessus de la moyenne mob… https://t.co/VyCxOPhGCx',
#   0,
#   1,
#   'CoignardDavid',
#   ''],
#  [datetime.datetime(2020, 4, 6, 7, 0),
#   'BCH / USD\n$239.93    |    +0.0017%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 7, 0),
#   'Participate with the Vontobel Crypto Portfolio in the performance of #BTC #BCH #ETH #LTC &amp; #XRP at once:… https://t.co/vNCTIKCNdN',
#   0,
#   3,
#   'Vontobel_SP_SE',
#   ''],
#  [datetime.datetime(2020, 4, 6, 6, 55, 42),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/nAwrYjh33e',
#   0,
#   4,
#   'SirToshiTV',
#   'The Metanet'],
#  [datetime.datetime(2020, 4, 6, 6, 53, 59),
#   'Our #daily update on #Cryptocurrency #Market \n\n#Blockchain #Innovation #Futureofmoney #Stablecoin #Bitcoin #BTC… https://t.co/twmK7etbqB',
#   0,
#   0,
#   'ceuzcoin',
#   ''],
#  [datetime.datetime(2020, 4, 6, 6, 42, 10),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n23,824 #BCH (5,561,240 USD) from unknow wallet to unkn… https://t.co/x1ezRlv53o',
#   0,
#   1,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 6, 0),
#   'BCH / USD\n$239.53    |    +0.0064%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 5, 50, 54),
#   '🏦 BSV and BCH Are Surging With Their Halvings a Month Before Bitcoin\n#BTCPeek #Bitcoin #Month #BitcoinCash #BCH… https://t.co/XVJQFeXUHp',
#   0,
#   0,
#   'SergheiPogor',
#   'Moldova'],
#  [datetime.datetime(2020, 4, 6, 5, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n10,109 #BCH (2,359,640 USD) from unknow wallet to unkn… https://t.co/bkSSJVGjd7',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 5, 13, 29),
#   '@realDonaldTrump @bitcoin @bitcoinsv @bitcoincash @bitcoincore @bsv @bch @btc @crypto @CalvinAyre @drcraigswright https://t.co/U2lE37eOQh',
#   0,
#   0,
#   'Nata54153323',
#   ''],
#  [datetime.datetime(2020, 4, 6, 5, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 20% \n▼DOWN 80%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/MTn9NVAfzg",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 6, 5, 0),
#   'BCH / USD\n$238.01    |    +0.0176%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 4, 52, 39),
#   '@kvetinko1 @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp… https://t.co/Zl23z0hopF',
#   0,
#   0,
#   'stevemorro101',
#   ''],
#  [datetime.datetime(2020, 4, 6, 4, 49, 17),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/fthf6RQGNr',
#   0,
#   0,
#   'stevemorro101',
#   ''],
#  [datetime.datetime(2020, 4, 6, 4, 29, 50),
#   '#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/XBHyFygxM5',
#   0,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 6, 4, 29, 27),
#   '😱😱\n#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/RKhyCypey4',
#   1,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 6, 4, 26, 11),
#   '#Bitcoin #btc #ethereum #eth #ripple #xrp #BitcoinCash #bch #litecoin #ltc #Dash #dogecoin #doge #eos #xlm #trx… https://t.co/8lZyttpcVu',
#   0,
#   1,
#   'ROzbayram',
#   ' '],
#  [datetime.datetime(2020, 4, 6, 4, 0),
#   'BCH / USD\n$233.90    |    +0.0022%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 3, 55, 44),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/OIqxlVlQSe',
#   0,
#   1,
#   'FredieStair',
#   'Great Southern Land'],
#  [datetime.datetime(2020, 4, 6, 3, 52, 20),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/DiWh0cLphS',
#   0,
#   0,
#   'FredieStair',
#   'Great Southern Land'],
#  [datetime.datetime(2020, 4, 6, 3, 5, 24),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/ugrTqFFXYV',
#   0,
#   0,
#   'sguv01',
#   'cryptoworld'],
#  [datetime.datetime(2020, 4, 6, 3, 0, 34),
#   '2020/04/06 12:00:34\r[ bitFlyer ] \rビットコイン[BTC/JPY]：744,223円\rイーサリアム[ETH/JPY]：15,577円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.0102円… https://t.co/2K7e419IFF',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 6, 3, 0),
#   'BCH / USD\n$233.39    |    -0.0035%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 2, 56, 23),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/Y6LJnNWn32',
#   0,
#   2,
#   'FelipeLanze',
#   'Em busca da verdade'],
#  [datetime.datetime(2020, 4, 6, 2, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n5,989 #BCH (1,398,110 USD) from multiple addresses to… https://t.co/teQGguFIaO',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 4, 6, 2, 30, 38),
#   "I'm helping scale #BitcoinCash $BCH by supporting @Bitcoin_ABC's 2020 Fundraiser for #BCH protocol development. Joi… https://t.co/6wbPCQkJhg",
#   0,
#   7,
#   'ukJpKMun03rpnUL',
#   ''],
#  [datetime.datetime(2020, 4, 6, 2, 10, 23),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/mTqnY3LteP',
#   0,
#   1,
#   'layman_crypto',
#   'Europe'],
#  [datetime.datetime(2020, 4, 6, 2, 0, 9),
#   'https://t.co/saX0K0wG1M\nThe Crypto Flow Intel Report for 4/6/20 now available\n \n#CFx #MachineLearning #Finance… https://t.co/pp1fBoDtgN',
#   0,
#   0,
#   'KeyMajorCoin',
#   'United States'],
#  [datetime.datetime(2020, 4, 6, 2, 0, 5),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.94,120.28 - DolarToday(Euro) Bsf.101,537.90 - bitcoin(BTC)$6,852.11… https://t.co/Y91FDdBQDb',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 4, 6, 2, 0),
#   'BCH / USD\n$234.22    |    -0.0056%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 1, 58, 25),
#   '2 days to go, very under the radar #Bitcoincash $bch https://t.co/NSMjyzmy9D',
#   1,
#   2,
#   'Globalnvest_',
#   ''],
#  [datetime.datetime(2020, 4, 6, 1, 37, 52),
#   'Message to the inhabitants of the #BitcoinCash ecosystem.\n“The important thing is this: to be able, at any moment,… https://t.co/wp8vtxIjU1',
#   0,
#   0,
#   'Leandro_DiMarco',
#   ''],
#  [datetime.datetime(2020, 4, 6, 1, 10, 4),
#   'Adult Entertainment Supported by Crypto Shoppers During Quarantine #bitcoin #blockchain #btc #bitcoincash #bch https://t.co/RlC6l4r2r6',
#   0,
#   1,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 6, 1, 10, 3),
#   'Stellar to Match XLM Donations to Six Non-Profits During April #binance #basis #bch #bitcoincash #bitcoin https://t.co/C6UKeYkQad',
#   0,
#   1,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 4, 6, 1, 5, 4),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 20% \n▼DOWN 80%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/HR2tWuuE2C",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 6, 1, 0, 1),
#   'BCH / USD\n$235.54    |    +0.0182%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 6, 0, 21, 37),
#   'The virus has overshadowed the #BitcoinCash #BCH halving coming up this Wednesday April 8th! https://t.co/PhvYycS54z',
#   0,
#   5,
#   'scotty321',
#   'Vancouver, British Columbia'],
#  [datetime.datetime(2020, 4, 6, 0, 0, 1),
#   'BCH / USD\n$231.32    |    -0.0010%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 39, 43),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/yq9lRhLt72',
#   0,
#   2,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 37, 38),
#   '@ABlastforever @StrictlyBidnazz @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy… https://t.co/fo1154OK8s',
#   0,
#   1,
#   'factcheckmypost',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 28),
#   '@valentinklimov @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp… https://t.co/6vfNZUjfKx',
#   0,
#   3,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 25, 41),
#   '@d7b @rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/Q6EmnamlNk',
#   2,
#   9,
#   'CryptoPanda15',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 25, 2),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/Q7Blf3imDJ',
#   0,
#   14,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 21, 30),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/rEA8He94QC',
#   0,
#   3,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 18, 17),
#   '@rogerkver @BitcoinCash @obpp_org @HavenPrivacy @PrivacyProject @futureofprivacy @PrivacyCamp @bitcoinshuffle… https://t.co/N3obh2pBnc',
#   0,
#   10,
#   'kvetinko1',
#   ''],
#  [datetime.datetime(2020, 4, 5, 23, 0, 1),
#   'BCH / USD\n$231.56    |    +0.0059%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 5, 22, 0, 1),
#   'BCH / USD\n$230.20    |    -0.0004%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 5, 21, 18, 11),
#   "Embattled TravelByBit says more than half their Australian BTC/LN stores don't want to be publicly listed but all r… https://t.co/ODCl3KTEiH",
#   1,
#   3,
#   'bchaustralia',
#   'Australia'],
#  [datetime.datetime(2020, 4, 5, 21, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 0% \n▼DOWN 0%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/7BU70dVPjL",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 4, 5, 21, 0, 8),
#   '2020/04/06 06:00:08\r[ bitFlyer ] \rビットコイン[BTC/JPY]：734,500円\rイーサリアム[ETH/JPY]：15,432円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30003.9813円… https://t.co/Ni0mUXPxyz',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 4, 5, 21, 0),
#   'BCH / USD\n$230.28    |    -0.0096%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 5, 20, 30, 2),
#   '$BCH/USD - buy on:@bithumbofficial - sell on:@livecoin_net - arbitrage:4.80%\n$BCH/BTC -  buy on:@cex_io - sell on:… https://t.co/2FBCM1UTDa',
#   0,
#   0,
#   'arbitragebot',
#   'Los Angeles, CA'],
#  [datetime.datetime(2020, 4, 5, 20, 0),
#   'BCH / USD\n$232.51    |    +0.0038%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 4, 5, 19, 53, 13),
# ...
#   'There is left just one week to #BitcoinCash halving. I am very interesting what will happen with network after this… https://t.co/TSzRDxGOkJ',
#   0,
#   3,
#   'dodo050595',
#   'Warsaw, Poland'],
#  [datetime.datetime(2020, 3, 31, 23, 0),
#   'BCH / USD\n$219.89    |    -0.0031%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 22, 0, 51),
#   'Price of 1 BCH to USD: $0.0 (Change: NaN %)\nPrice of 1 BCH to BTC:  Ƀ (Change: NaN %)\n#bitcoincash #bch $bch',
#   0,
#   1,
#   'bch_price',
#   'World'],
#  [datetime.datetime(2020, 3, 31, 22, 0),
#   'BCH / USD\n$220.57    |    -0.0042%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 21, 8),
#   'CFxMLRS profile for 03/31/20\n\nMore Live Updates 24/7 @\nhttps://t.co/LodmWIvwaF\n\n#CFx #MachineLearning #Finance… https://t.co/OsdkGR92mB',
#   1,
#   2,
#   'KeyMajorCoin',
#   'United States'],
#  [datetime.datetime(2020, 3, 31, 21, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 50% \n▼DOWN 50%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/Eqmf0jG5rA",
#   0,
#   1,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 3, 31, 21, 0, 8),
#   '2020/04/01 06:00:08\r[ bitFlyer ] \rビットコイン[BTC/JPY]：697,581円\rイーサリアム[ETH/JPY]：14,328円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30003.9545円… https://t.co/6vB2QmSmJd',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 3, 31, 21, 0),
#   'BCH / USD\n$221.51    |    +0.0072%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 20, 15, 36),
#   'Blockchain Poker Reaches Record Traffic During Coronavirus Pandemic, Powered by #BitcoinCash #BCH. This is b/c BCH… https://t.co/buG3rY6yJu',
#   0,
#   3,
#   'scotty321',
#   'Vancouver, British Columbia'],
#  [datetime.datetime(2020, 3, 31, 20, 0),
#   'BCH / USD\n$219.93    |    -0.0021%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 19, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n11,792 #BCH (2,599,680 USD) from multiple addresses to… https://t.co/zXaLoJgDdj',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 19, 23, 52),
#   'BCH, BSV Block Halvings Will Force Miners to #Bitcoin (BTC) — Report - #BitcoinCash #BitcoinMining #BitcoinSV… https://t.co/3FDUqdKS99',
#   0,
#   0,
#   'PaulESamson',
#   'Bathurst, New Brunswick, Canada'],
#  [datetime.datetime(2020, 3, 31, 19, 15),
#   'Bitcoin ABC 0.21.3 has been released. Changes include new listwalletdir RPC, various RPC bug fixes, and improved lo… https://t.co/cUfBM8TfjY',
#   7,
#   29,
#   'Bitcoin_ABC',
#   ''],
#  [datetime.datetime(2020, 3, 31, 19, 0),
#   'BCH / USD\n$220.39    |    +0.0027%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 18, 54, 59),
#   '#leverage $btc $eth $bnb $kcs $tron $neo $xrp $ltc $bch $eos $omg $xmr $dash $zec $waves $bat $doge $zil $link… https://t.co/oc3zgtv7SY',
#   0,
#   2,
#   'Cryptoupdates',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 18, 15, 2),
#   'In last 24 hours, among top 10 #cryptocurrencies Bitcoin Cash (BCH) got the best % change (7.16 %) in price ,  Wher… https://t.co/XH7unhwqXF',
#   0,
#   0,
#   'CurrencyBuzzer',
#   ''],
#  [datetime.datetime(2020, 3, 31, 18, 0, 24),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.87,076.65 - DolarToday(Euro) Bsf.95,180.00 - bitcoin(BTC)$6,475.00… https://t.co/8myyEUnmjz',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 3, 31, 18, 0, 1),
#   'If you enjoyed this thread, maybe drop me some $BCH or $BTC:\n\nbitcoincash:qzr7c76wnlumem4llwxadc2ak2sxv28c3yutmd8yk… https://t.co/zJRZHTngOu',
#   4,
#   17,
#   'NotAnarchyball',
#   ''],
#  [datetime.datetime(2020, 3, 31, 18, 0),
#   'BCH / USD\n$219.79    |    -0.0011%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 17, 8, 48),
#   'Bitcoin Cash Price Analysis: BCH/USD the key for direction is a break above $225-50 range https://t.co/V0p27pEJPe… https://t.co/WeTbAaTxpQ',
#   0,
#   0,
#   'FxScrypto',
#   ''],
#  [datetime.datetime(2020, 3, 31, 17, 0),
#   'BCH / USD\n$220.03    |    -0.0034%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 16, 20, 28),
#   'Sin olvidar el pago en #BitcoinCash de su app hermana Free Bitcoin Cash!\n+22.732 #Satoshi pa la saca!\n\nDescarga est… https://t.co/XHEHgiqDHl',
#   0,
#   1,
#   'ElPTCPost',
#   'Barcelona, España'],
#  [datetime.datetime(2020, 3, 31, 16, 9, 41),
#   'Bitcoin Hash Rate Drop: Miners, the Halving and Coronavirus Suspected #analytics #bch #bitcoin #bitcoincash #asic https://t.co/v05jzZn1QJ',
#   0,
#   0,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 3, 31, 16, 0),
#   'BCH / USD\n$220.77    |    -0.0001%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 15, 48, 27),
#   'We just hit the Milestone of 1,300 Wallet Addresses. Built on Bitcoin Cash powered by @SimpleLedger \n\n#RNEW #BCH #BitcoinCash #Simpleledger',
#   2,
#   7,
#   'RNEW_Cash',
#   'London, UK'],
#  [datetime.datetime(2020, 3, 31, 15, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n28,265 #BCH (6,231,500 USD) from unknow wallet to unkn… https://t.co/YraNFqnDYS',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 15, 39, 47),
#   'The Crypto Industrys $400M Cash and Stock Deal - Binance to Acquire Coinmarketcapcom  #bitcoin News #CoinMarketCap… https://t.co/Xqfva22iSK',
#   0,
#   1,
#   'bitcoinagile',
#   "Matter Doesn't Matter"],
#  [datetime.datetime(2020, 3, 31, 15, 9, 36),
#   'BCH, BSV Block Halvings Will Force Miners to Bitcoin (BTC) — Report #bitcoincash #bch #btc #bitcoin #bitcoinmining https://t.co/JvZgiuRi1J',
#   0,
#   1,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 3, 31, 15, 3, 28),
#   'BCH Current Price (USD): $ 220.95 Vol: BCH 215,057.2 Change (24h): 1.46% $BCH #Bitcoincash',
#   0,
#   0,
#   'AnalysisInChain',
#   ''],
#  [datetime.datetime(2020, 3, 31, 15, 1, 3),
#   'I just updated the links in this article on how to become a  #FullStack   #developer  on the  #BitcoinCash   #BCH… https://t.co/uGeZV3fVXn',
#   0,
#   0,
#   'memofwd',
#   ''],
#  [datetime.datetime(2020, 3, 31, 15, 0, 1),
#   'BCH / USD\n$220.79    |    +0.0023%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 14, 55),
#   'I just updated the links in this article on how to become a #FullStack #developer on the #BitcoinCash #BCH network.… https://t.co/ezQ4qp2qF8',
#   8,
#   19,
#   'christroutner',
#   'Anacortes, Washington'],
#  [datetime.datetime(2020, 3, 31, 14, 18, 42),
#   'BCH, BSV Block Halvings Will Force Miners to #bitcoin (BTC) — Report #Mining #BitcoinMining #Markets #BitcoinCash… https://t.co/tZemn7wHki',
#   0,
#   0,
#   'bitcoinagile',
#   "Matter Doesn't Matter"],
#  [datetime.datetime(2020, 3, 31, 14, 5, 4),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 50% \n▼DOWN 50%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/bzdr0DzNGJ",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 3, 31, 14, 2, 32),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: @BITCOlNCASH On distingue une tendance haussière sur BITCOIN CASH - BCH/USD aussi b… https://t.co/mfb75vq5Nt',
#   0,
#   0,
#   'CentralCharts',
#   ''],
#  [datetime.datetime(2020, 3, 31, 14, 0, 1),
#   'BCH / USD\n$220.28    |    -0.0011%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 14, 0),
#   '$BCH $BCHUSD #BITCOINCASH - 1H: On distingue une tendance haussière sur BITCOIN CASH - BCH/USD aussi bien sur le fo… https://t.co/IrXzkM6ePU',
#   0,
#   0,
#   'Lutessia_IA',
#   ''],
#  [datetime.datetime(2020, 3, 31, 13, 44, 48),
#   'The next Japan virtual #BitcoinCash meetup with friends, is happening tomorrow Wed April 1! Please RSVP to join. We… https://t.co/l4aUzqCS7E',
#   4,
#   19,
#   'YokooAkane',
#   'Minato-ku, Tokyo'],
#  [datetime.datetime(2020, 3, 31, 13, 19),
#   '#Hello #BitcoinCash | Stay Heatlhy with Aromatherapy | $BCH #BCH https://t.co/9aTxJNS71e',
#   0,
#   1,
#   'VAPEPENstore',
#   'Florida, US'],
#  [datetime.datetime(2020, 3, 31, 13, 2, 35),
#   '#bitcoin Halving is Just 43 Days Away, BTC Price Is Around $6,400 #bch #bitcoincash #bitcoinhalving… https://t.co/dBPhW113tD',
#   0,
#   0,
#   'bitcoinagile',
#   "Matter Doesn't Matter"],
#  [datetime.datetime(2020, 3, 31, 13, 0, 13),
#   '#BitcoinCash is innovating with new privacy tools.🕵️\n\nMore than 18,000 $BCH has been fused using #CashFusion and mo… https://t.co/sO7eDHCreu',
#   3,
#   14,
#   'BitcoinUnlimit',
#   'Global'],
#  [datetime.datetime(2020, 3, 31, 13, 0),
#   'BCH / USD\n$220.52    |    +0.0075%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 12, 56, 23),
#   '@rogerkver @BitcoinCash Just give it up dude bch is a shitcoin like other 5k of them yea people can choose to use it but its not bitcoin',
#   0,
#   0,
#   'dc77ae00b817435',
#   'SoFL'],
#  [datetime.datetime(2020, 3, 31, 12, 47, 33),
#   '“Will This Black Swan Pressure Crypto Regulations?”\n\nhttps://t.co/nwx5gMJTfx\n\n#Bitcoin #Ethereum #BitcoinCash… https://t.co/qyq7EP9CWS',
#   0,
#   2,
#   'KeyMajorCoin',
#   'United States'],
#  [datetime.datetime(2020, 3, 31, 12, 42, 8),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n14,634 #BCH (3,226,260 USD) from multiple addresses to… https://t.co/wbGeupni9e',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 12, 24, 48),
#   "#BCH  What an amazing short + long entry here, let's go. \n#BitcoinCash #gains #cryptocurrency #cryptotrading… https://t.co/rKVoO9BonO",
#   0,
#   0,
#   'CryptoRacoons',
#   'Not financial advice'],
#  [datetime.datetime(2020, 3, 31, 12, 0),
#   'BCH / USD\n$218.89    |    -0.0059%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 11, 50, 18),
#   '@KanoTheTruth @username_Dizzy @EltonLu @MyLegacyKit @CalvinAyre @VelvelFreedman @JimmyWinMedia @KyleWRoche… https://t.co/4sOZSjPHko',
#   0,
#   1,
#   'tututpouet',
#   ''],
#  [datetime.datetime(2020, 3, 31, 11, 23, 41),
#   "InstaCrypto's online meetup brought more blockchain developers this time... Some benefits of work from home.… https://t.co/wFMGlxXEAc",
#   1,
#   2,
#   'InstaCryptoIN',
#   'Bengaluru, India'],
#  [datetime.datetime(2020, 3, 31, 11, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 50% \n▼DOWN 50%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/giOPL8NKKm",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 3, 31, 11, 1, 38),
#   '@MartinAudley @JasonEbacher @rogerkver @BitcoinCash Does anyone use BCH? =)',
#   0,
#   0,
#   'rand_0m',
#   ''],
#  [datetime.datetime(2020, 3, 31, 11, 0),
#   'BCH / USD\n$220.19    |    +0.0014%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 10, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n20,000 #BCH (4,409,400 USD) from multiple addresses to… https://t.co/wLytYpansH',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 10, 0, 56),
#   'Cotizaciones del momento 💰: DolarToday(USD) Bsf.84,581.04 - DolarToday(Euro) Bsf.93,613.45 - bitcoin(BTC)$6,446.97… https://t.co/W6LViQjbS6',
#   0,
#   0,
#   'mykurrencies',
#   ''],
#  [datetime.datetime(2020, 3, 31, 10, 0),
#   'BCH / USD\n$219.88    |    -0.0086%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 9, 50, 6),
#   'Hoy: March 30, 2020 at 05:50AM, 1 BCH equivale a: 219.31 USD. #bitcoincash #bch #trading #mercados',
#   0,
#   0,
#   'blancomorao',
#   'Venezuela'],
#  [datetime.datetime(2020, 3, 31, 9, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n48,707 #BCH (10,738,400 USD) from multiple addresses t… https://t.co/GlTsssGFq6',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 9, 22, 10),
#   'I use hybrix to/for:\nhttps://t.co/0FMNbfZhtG\n\n#hybrix #crypto #cryptocurrency #CryptoTwitter #BTC #ethereum #XRP… https://t.co/erB2WmE5sj',
#   9,
#   10,
#   'hybrix_io',
#   'The Netherlands'],
#  [datetime.datetime(2020, 3, 31, 9, 0, 32),
#   '2020/03/31 18:00:32\r[ bitFlyer ] \rビットコイン[BTC/JPY]：707,418円\rイーサリアム[ETH/JPY]：14,573円\r\r[ Zaif ] \rネム[XEM/JPY]：\u3000\u30004.015円… https://t.co/jM9ewfWfxl',
#   0,
#   0,
#   'coinonedan',
#   '東京 渋谷区'],
#  [datetime.datetime(2020, 3, 31, 9, 0),
#   'BCH / USD\n$221.79    |    +0.0130%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 8, 55, 24),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2 https://t.co/3QaFUPGvrJ',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 3, 31, 8, 54, 39),
#   'BCH address: bitcoincash:qruad3auw2czuksrfjq24a8jqahhevl3wqshujftt2',
#   0,
#   0,
#   'titeldaniel',
#   'Slatina, România'],
#  [datetime.datetime(2020, 3, 31, 8, 46, 8),
#   '#BTC = $6,443.44\n#ETH = $131.70\n#XRP = $0.172691\n#BCH = $219.03\n\nLatest prices of different #cryptocurrencies\nFollo… https://t.co/VBctjuQRP9',
#   0,
#   0,
#   'nioc_exchange',
#   'Estonia'],
#  [datetime.datetime(2020, 3, 31, 8, 38, 43),
#   'Top 5 European #fintech Payment Companies to Watch in 2020 #ethereum #bitcoin #bch #bitcoincash #btc #eth… https://t.co/4h1yI0aPWI',
#   0,
#   0,
#   'bitcoinagile',
#   "Matter Doesn't Matter"],
#  [datetime.datetime(2020, 3, 31, 8, 30, 1),
#   '$BCH/USD - buy on:@bitbns - sell on:@exmo_com - arbitrage:6.00%\n$BCH/BTC -  buy on:@upbitglobal - sell on:@finexbox… https://t.co/EEOKAutR9s',
#   0,
#   1,
#   'arbitragebot',
#   'Los Angeles, CA'],
#  [datetime.datetime(2020, 3, 31, 8, 26, 43),
#   '@rogerkver @BitcoinCash Same. BCH is awesome',
#   0,
#   7,
#   'wisewizzz',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 8, 9, 58),
#   'Coinbase Reports Record Bitcoin Buying Amid March 12 Crash #bitcoincash #ban #bitcoin #btc #bch https://t.co/Vtp2QG1pv7',
#   0,
#   2,
#   'CashTechNews',
#   'New York, NY'],
#  [datetime.datetime(2020, 3, 31, 8, 2, 42),
#   'https://t.co/vCNztABJoG Exchange lists $BCH! Trade BCH in $BTC, $USDT &amp; $CRO pairs now. #BCH #BitcoinCash https://t.co/aU9NxxvQNN',
#   66,
#   263,
#   'cryptocom',
#   ''],
#  [datetime.datetime(2020, 3, 31, 8, 0),
#   'BCH / USD\n$218.96    |    -0.0027%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 7, 49, 15),
#   'Live Market Update from the CMC dealing desk - Crypto:\n#Bitcoin  6443.11 -0.55%\n#Ethereum  131.85 -1.7%… https://t.co/IuEwALU5cQ',
#   0,
#   1,
#   'CMCMarkets',
#   'Content is not advice'],
#  [datetime.datetime(2020, 3, 31, 7, 46, 20),
#   'Our #daily update on #Cryptocurrency #Market \n\n#Blockchain #Innovation #Futureofmoney #Stablecoin #Bitcoin #BTC… https://t.co/Oo9mPSFQyp',
#   0,
#   0,
#   'ceuzcoin',
#   ''],
#  [datetime.datetime(2020, 3, 31, 7, 27, 42),
#   '@rogerkver @BitcoinCash BCH left Bitcoin too... and you know it!!!',
#   0,
#   2,
#   'cryptojubilado',
#   ''],
#  [datetime.datetime(2020, 3, 31, 7, 0),
#   'BCH / USD\n$219.56    |    +0.0094%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 6, 6, 1),
#   'NOW LIVE for 24 Hours Only🔥! $BCH is 5⃣0⃣% off ($500K USD allocation). Sign up for Exchange, stake $CRO, and subscr… https://t.co/06wed1kQhu',
#   63,
#   198,
#   'cryptocom',
#   ''],
#  [datetime.datetime(2020, 3, 31, 6, 0),
#   'BCH / USD\n$217.52    |    +0.0026%📈\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   ''],
#  [datetime.datetime(2020, 3, 31, 5, 42, 9),
#   'Last hourly biggest #BITCOINCASH blockchain transaction : \n \n16,218 #BCH (3,575,630 USD) from multiple addresses to… https://t.co/ASsmLWDZ2D',
#   0,
#   0,
#   'ClankApp',
#   'Moon'],
#  [datetime.datetime(2020, 3, 31, 5, 33, 47),
#   'Bitcoin Cash (BCH / USD) se négocie à 209. Les cotations de crypto-monnaie se négocient en dessous de la moyenne mo… https://t.co/n5EJXimAIJ',
#   0,
#   0,
#   'CoignardDavid',
#   ''],
#  [datetime.datetime(2020, 3, 31, 5, 5, 3),
#   "Tomorrow's Bitcoincash(BCH) forecast is\n        \n△UP 50% \n▼DOWN 50%\n\n#Bitcoincash, #BCH\n\nBitcoin Forecast (iOS)… https://t.co/sCm1mdJ7ft",
#   0,
#   0,
#   'ccexapp',
#   'Tokyo-to, Japan'],
#  [datetime.datetime(2020, 3, 31, 5, 0),
#   'BCH / USD\n$216.96    |    -0.0126%📉\n#BCHUSD #BitcoinCash',
#   0,
#   0,
#   'BchPulse',
#   '']]

# %%
#and then make a dataframe
df = pd.DataFrame(justthegoodstuff, columns=['created_at','text','retweet_count','favorite_count','screenname','location'])

# %%
df
# Out:
#              created_at                                               text  \
# 0   2020-04-07 19:22:38  Les mineurs de Bitcoin Cash changent de camp a...
# 1   2020-04-07 19:10:08  #BitcoinCash has 105 blocks to go until halvin...
# 2   2020-04-07 19:07:17  This is why #BitcoinCash #BCH was created. It ...
# 3   2020-04-07 19:04:18  BCH Current Price (USD): $ 258.07 Vol: BCH 233...
# 4   2020-04-07 19:00:00  BCH / USD\n$256.46    |    -0.0096%📉\n#BCHUSD ...
# 5   2020-04-07 18:58:19  @HuobiGlobal @CoinMarketCal @BitcoinCash #BCH ...
# 6   2020-04-07 18:00:26  Cotizaciones del momento 💰: DolarToday(USD) Bs...
# 7   2020-04-07 18:00:03  In last 24 hours, among top 10 #cryptocurrenci...
# 8   2020-04-07 18:00:00  BCH / USD\n$258.95    |    -0.0065%📉\n#BCHUSD ...
# 9   2020-04-07 17:32:14  Roughly one third of the total circulating Bit...
# 10  2020-04-07 17:00:00  BCH / USD\n$260.65    |    +0.0105%📈\n#BCHUSD ...
# 11  2020-04-07 16:49:05  One-Third of Bitcoin Cash's Supply Has Never B...
# 12  2020-04-07 16:43:11  #Bitcoin /#BitcoinCash giveaway. To help with ...
# 13  2020-04-07 16:43:08  The #BitcoinCash #halving is expected to occur...
# 14  2020-04-07 16:30:01  $BCH/USD - buy on:@okcoin - sell on:@exmo_com ...
# 15  2020-04-07 16:28:37  Bitcoin Cash Price Forecast: BCH/USD bulls eye...
# 16  2020-04-07 16:17:30  "Making Money Wasnt Easy ... But making more m...
# 17  2020-04-07 16:09:56  One-Third of Bitcoin Cash's Supply Has Never B...
# 18  2020-04-07 16:08:48  BCH Is Halving :P nobody care #Crypto \n$bitco...
# 19  2020-04-07 16:03:25  The #bitcoincash halving is in less than 24 ho...
# 20  2020-04-07 16:00:00  BCH / USD\n$257.95    |    +0.0129%📈\n#BCHUSD ...
# 21  2020-04-07 15:50:00  Permissionless unstoppable private peer-to-pee...
# 22  2020-04-07 15:49:23  Crypto update:\n#Bitcoin 7300.21 +0.96%\n#Ethe...
# 23  2020-04-07 15:43:31  Welke 3 #crypto moet je deze week in de gaten ...
# 24  2020-04-07 15:37:42  Watch the Bitcoin Cash block reward halving li...
# 25  2020-04-07 15:08:27  Ether going down. Look for support around 164-...
# 26  2020-04-07 15:00:00  BCH / USD\n$254.67    |    -0.0164%📉\n#BCHUSD ...
# 27  2020-04-07 14:15:43  #BitcoinCash is up 5.64% on the day.\n#BCH is ...
# 28  2020-04-07 14:05:04  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 29  2020-04-07 14:00:00  BCH / USD\n$258.92    |    +0.0027%📈\n#BCHUSD ...
# ..                  ...                                                ...
# 740 2020-03-31 11:05:03  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 741 2020-03-31 11:01:38  @MartinAudley @JasonEbacher @rogerkver @Bitcoi...
# 742 2020-03-31 11:00:00  BCH / USD\n$220.19    |    +0.0014%📈\n#BCHUSD ...
# 743 2020-03-31 10:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 744 2020-03-31 10:00:56  Cotizaciones del momento 💰: DolarToday(USD) Bs...
# 745 2020-03-31 10:00:00  BCH / USD\n$219.88    |    -0.0086%📉\n#BCHUSD ...
# 746 2020-03-31 09:50:06  Hoy: March 30, 2020 at 05:50AM, 1 BCH equivale...
# 747 2020-03-31 09:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 748 2020-03-31 09:22:10  I use hybrix to/for:\nhttps://t.co/0FMNbfZhtG\...
# 749 2020-03-31 09:00:32  2020/03/31 18:00:32\r[ bitFlyer ] \rビットコイン[BTC...
# 750 2020-03-31 09:00:00  BCH / USD\n$221.79    |    +0.0130%📈\n#BCHUSD ...
# 751 2020-03-31 08:55:24  BCH address: bitcoincash:qruad3auw2czuksrfjq24...
# 752 2020-03-31 08:54:39  BCH address: bitcoincash:qruad3auw2czuksrfjq24...
# 753 2020-03-31 08:46:08  #BTC = $6,443.44\n#ETH = $131.70\n#XRP = $0.17...
# 754 2020-03-31 08:38:43  Top 5 European #fintech Payment Companies to W...
# 755 2020-03-31 08:30:01  $BCH/USD - buy on:@bitbns - sell on:@exmo_com ...
# 756 2020-03-31 08:26:43       @rogerkver @BitcoinCash Same. BCH is awesome
# 757 2020-03-31 08:09:58  Coinbase Reports Record Bitcoin Buying Amid Ma...
# 758 2020-03-31 08:02:42  https://t.co/vCNztABJoG Exchange lists $BCH! T...
# 759 2020-03-31 08:00:00  BCH / USD\n$218.96    |    -0.0027%📉\n#BCHUSD ...
# 760 2020-03-31 07:49:15  Live Market Update from the CMC dealing desk -...
# 761 2020-03-31 07:46:20  Our #daily update on #Cryptocurrency #Market \...
# 762 2020-03-31 07:27:42  @rogerkver @BitcoinCash BCH left Bitcoin too.....
# 763 2020-03-31 07:00:00  BCH / USD\n$219.56    |    +0.0094%📈\n#BCHUSD ...
# 764 2020-03-31 06:06:01  NOW LIVE for 24 Hours Only🔥! $BCH is 5⃣0⃣% off...
# 765 2020-03-31 06:00:00  BCH / USD\n$217.52    |    +0.0026%📈\n#BCHUSD ...
# 766 2020-03-31 05:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 767 2020-03-31 05:33:47  Bitcoin Cash (BCH / USD) se négocie à 209. Les...
# 768 2020-03-31 05:05:03  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 769 2020-03-31 05:00:00  BCH / USD\n$216.96    |    -0.0126%📉\n#BCHUSD ...
#
#      retweet_count  favorite_count       screenname  \
# 0                0               0    cryptonews_FR
# 1                0               2       AtlasPulse
# 2                0               0        scotty321
# 3                0               0  AnalysisInChain
# 4                0               0         BchPulse
# 5                0               0         tamilbtc
# 6                0               0     mykurrencies
# 7                0               0   CurrencyBuzzer
# 8                0               0         BchPulse
# 9                0               0       ToshiTimes
# 10               0               0         BchPulse
# 11               0               0   BitcoINstagram
# 12              10               8    BitcoinToilet
# 13               0               1        CoinCodex
# 14               0               0     arbitragebot
# 15               4               0        FxScrypto
# 16               1               5     BCH_Ventures
# 17               0               0     CashTechNews
# 18               0               0     farrukhm2010
# 19               1               0     Titan_Mining
# 20               0               0         BchPulse
# 21               8              23         CoinText
# 22               0               1    PhoenixSquawk
# 23               0               0    CryptoCoinBit
# 24               0               2       Coin_Dance
# 25               0               3         zabisara
# 26               1               1         BchPulse
# 27               0               1      CryptoPolka
# 28               0               1          ccexapp
# 29               0               0         BchPulse
# ..             ...             ...              ...
# 740              0               0          ccexapp
# 741              0               0          rand_0m
# 742              0               0         BchPulse
# 743              0               0         ClankApp
# 744              0               0     mykurrencies
# 745              0               0         BchPulse
# 746              0               0      blancomorao
# 747              0               0         ClankApp
# 748              9              10        hybrix_io
# 749              0               0       coinonedan
# 750              0               0         BchPulse
# 751              0               0      titeldaniel
# 752              0               0      titeldaniel
# 753              0               0    nioc_exchange
# 754              0               0     bitcoinagile
# 755              0               1     arbitragebot
# 756              0               7        wisewizzz
# 757              0               2     CashTechNews
# 758             66             263        cryptocom
# 759              0               0         BchPulse
# 760              0               1       CMCMarkets
# 761              0               0         ceuzcoin
# 762              0               2   cryptojubilado
# 763              0               0         BchPulse
# 764             63             198        cryptocom
# 765              0               0         BchPulse
# 766              0               0         ClankApp
# 767              0               0    CoignardDavid
# 768              0               0          ccexapp
# 769              0               0         BchPulse
#
#                            location
# 0                  Montréal, Québec
# 1                                UK
# 2       Vancouver, British Columbia
# 3
# 4
# 5                             India
# 6
# 7
# 8
# 9                     New York, USA
# 10
# 11                    United States
# 12              North Carolina, USA
# 13
# 14                  Los Angeles, CA
# 15
# 16   SHOP A4 IFEMELUNMA PLAZA, OKPU
# 17                     New York, NY
# 18              Islamabad, Pakistan
# 19
# 20
# 21                          Onchain
# 22
# 23
# 24
# 25            Dark Side Of The Moon
# 26
# 27                            Earth
# 28                  Tokyo-to, Japan
# 29
# ..                              ...
# 740                 Tokyo-to, Japan
# 741
# 742
# 743                            Moon
# 744
# 745
# 746                       Venezuela
# 747                            Moon
# 748                 The Netherlands
# 749                          東京 渋谷区
# 750
# 751                Slatina, România
# 752                Slatina, România
# 753                         Estonia
# 754           Matter Doesn't Matter
# 755                 Los Angeles, CA
# 756                            Moon
# 757                    New York, NY
# 758
# 759
# 760           Content is not advice
# 761
# 762
# 763
# 764
# 765
# 766                            Moon
# 767
# 768                 Tokyo-to, Japan
# 769
#
# [770 rows x 6 columns]

# %%
from afinn import Afinn
afinn = Afinn(emoticons=True)
df['sentiment'] = df.apply (lambda row: afinn.score(row['text']), axis=1)
df.keys()
# Out:
# Index(['created_at', 'text', 'retweet_count', 'favorite_count', 'screenname',
#        'location', 'sentiment'],
#       dtype='object')

# %%
df
# Out:
#              created_at                                               text  \
# 0   2020-04-07 19:22:38  Les mineurs de Bitcoin Cash changent de camp a...
# 1   2020-04-07 19:10:08  #BitcoinCash has 105 blocks to go until halvin...
# 2   2020-04-07 19:07:17  This is why #BitcoinCash #BCH was created. It ...
# 3   2020-04-07 19:04:18  BCH Current Price (USD): $ 258.07 Vol: BCH 233...
# 4   2020-04-07 19:00:00  BCH / USD\n$256.46    |    -0.0096%📉\n#BCHUSD ...
# 5   2020-04-07 18:58:19  @HuobiGlobal @CoinMarketCal @BitcoinCash #BCH ...
# 6   2020-04-07 18:00:26  Cotizaciones del momento 💰: DolarToday(USD) Bs...
# 7   2020-04-07 18:00:03  In last 24 hours, among top 10 #cryptocurrenci...
# 8   2020-04-07 18:00:00  BCH / USD\n$258.95    |    -0.0065%📉\n#BCHUSD ...
# 9   2020-04-07 17:32:14  Roughly one third of the total circulating Bit...
# 10  2020-04-07 17:00:00  BCH / USD\n$260.65    |    +0.0105%📈\n#BCHUSD ...
# 11  2020-04-07 16:49:05  One-Third of Bitcoin Cash's Supply Has Never B...
# 12  2020-04-07 16:43:11  #Bitcoin /#BitcoinCash giveaway. To help with ...
# 13  2020-04-07 16:43:08  The #BitcoinCash #halving is expected to occur...
# 14  2020-04-07 16:30:01  $BCH/USD - buy on:@okcoin - sell on:@exmo_com ...
# 15  2020-04-07 16:28:37  Bitcoin Cash Price Forecast: BCH/USD bulls eye...
# 16  2020-04-07 16:17:30  "Making Money Wasnt Easy ... But making more m...
# 17  2020-04-07 16:09:56  One-Third of Bitcoin Cash's Supply Has Never B...
# 18  2020-04-07 16:08:48  BCH Is Halving :P nobody care #Crypto \n$bitco...
# 19  2020-04-07 16:03:25  The #bitcoincash halving is in less than 24 ho...
# 20  2020-04-07 16:00:00  BCH / USD\n$257.95    |    +0.0129%📈\n#BCHUSD ...
# 21  2020-04-07 15:50:00  Permissionless unstoppable private peer-to-pee...
# 22  2020-04-07 15:49:23  Crypto update:\n#Bitcoin 7300.21 +0.96%\n#Ethe...
# 23  2020-04-07 15:43:31  Welke 3 #crypto moet je deze week in de gaten ...
# 24  2020-04-07 15:37:42  Watch the Bitcoin Cash block reward halving li...
# 25  2020-04-07 15:08:27  Ether going down. Look for support around 164-...
# 26  2020-04-07 15:00:00  BCH / USD\n$254.67    |    -0.0164%📉\n#BCHUSD ...
# 27  2020-04-07 14:15:43  #BitcoinCash is up 5.64% on the day.\n#BCH is ...
# 28  2020-04-07 14:05:04  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 29  2020-04-07 14:00:00  BCH / USD\n$258.92    |    +0.0027%📈\n#BCHUSD ...
# ..                  ...                                                ...
# 740 2020-03-31 11:05:03  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 741 2020-03-31 11:01:38  @MartinAudley @JasonEbacher @rogerkver @Bitcoi...
# 742 2020-03-31 11:00:00  BCH / USD\n$220.19    |    +0.0014%📈\n#BCHUSD ...
# 743 2020-03-31 10:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 744 2020-03-31 10:00:56  Cotizaciones del momento 💰: DolarToday(USD) Bs...
# 745 2020-03-31 10:00:00  BCH / USD\n$219.88    |    -0.0086%📉\n#BCHUSD ...
# 746 2020-03-31 09:50:06  Hoy: March 30, 2020 at 05:50AM, 1 BCH equivale...
# 747 2020-03-31 09:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 748 2020-03-31 09:22:10  I use hybrix to/for:\nhttps://t.co/0FMNbfZhtG\...
# 749 2020-03-31 09:00:32  2020/03/31 18:00:32\r[ bitFlyer ] \rビットコイン[BTC...
# 750 2020-03-31 09:00:00  BCH / USD\n$221.79    |    +0.0130%📈\n#BCHUSD ...
# 751 2020-03-31 08:55:24  BCH address: bitcoincash:qruad3auw2czuksrfjq24...
# 752 2020-03-31 08:54:39  BCH address: bitcoincash:qruad3auw2czuksrfjq24...
# 753 2020-03-31 08:46:08  #BTC = $6,443.44\n#ETH = $131.70\n#XRP = $0.17...
# 754 2020-03-31 08:38:43  Top 5 European #fintech Payment Companies to W...
# 755 2020-03-31 08:30:01  $BCH/USD - buy on:@bitbns - sell on:@exmo_com ...
# 756 2020-03-31 08:26:43       @rogerkver @BitcoinCash Same. BCH is awesome
# 757 2020-03-31 08:09:58  Coinbase Reports Record Bitcoin Buying Amid Ma...
# 758 2020-03-31 08:02:42  https://t.co/vCNztABJoG Exchange lists $BCH! T...
# 759 2020-03-31 08:00:00  BCH / USD\n$218.96    |    -0.0027%📉\n#BCHUSD ...
# 760 2020-03-31 07:49:15  Live Market Update from the CMC dealing desk -...
# 761 2020-03-31 07:46:20  Our #daily update on #Cryptocurrency #Market \...
# 762 2020-03-31 07:27:42  @rogerkver @BitcoinCash BCH left Bitcoin too.....
# 763 2020-03-31 07:00:00  BCH / USD\n$219.56    |    +0.0094%📈\n#BCHUSD ...
# 764 2020-03-31 06:06:01  NOW LIVE for 24 Hours Only🔥! $BCH is 5⃣0⃣% off...
# 765 2020-03-31 06:00:00  BCH / USD\n$217.52    |    +0.0026%📈\n#BCHUSD ...
# 766 2020-03-31 05:42:09  Last hourly biggest #BITCOINCASH blockchain tr...
# 767 2020-03-31 05:33:47  Bitcoin Cash (BCH / USD) se négocie à 209. Les...
# 768 2020-03-31 05:05:03  Tomorrow's Bitcoincash(BCH) forecast is\n     ...
# 769 2020-03-31 05:00:00  BCH / USD\n$216.96    |    -0.0126%📉\n#BCHUSD ...
#
#      retweet_count  favorite_count       screenname  \
# 0                0               0    cryptonews_FR
# 1                0               2       AtlasPulse
# 2                0               0        scotty321
# 3                0               0  AnalysisInChain
# 4                0               0         BchPulse
# 5                0               0         tamilbtc
# 6                0               0     mykurrencies
# 7                0               0   CurrencyBuzzer
# 8                0               0         BchPulse
# 9                0               0       ToshiTimes
# 10               0               0         BchPulse
# 11               0               0   BitcoINstagram
# 12              10               8    BitcoinToilet
# 13               0               1        CoinCodex
# 14               0               0     arbitragebot
# 15               4               0        FxScrypto
# 16               1               5     BCH_Ventures
# 17               0               0     CashTechNews
# 18               0               0     farrukhm2010
# 19               1               0     Titan_Mining
# 20               0               0         BchPulse
# 21               8              23         CoinText
# 22               0               1    PhoenixSquawk
# 23               0               0    CryptoCoinBit
# 24               0               2       Coin_Dance
# 25               0               3         zabisara
# 26               1               1         BchPulse
# 27               0               1      CryptoPolka
# 28               0               1          ccexapp
# 29               0               0         BchPulse
# ..             ...             ...              ...
# 740              0               0          ccexapp
# 741              0               0          rand_0m
# 742              0               0         BchPulse
# 743              0               0         ClankApp
# 744              0               0     mykurrencies
# 745              0               0         BchPulse
# 746              0               0      blancomorao
# 747              0               0         ClankApp
# 748              9              10        hybrix_io
# 749              0               0       coinonedan
# 750              0               0         BchPulse
# 751              0               0      titeldaniel
# 752              0               0      titeldaniel
# 753              0               0    nioc_exchange
# 754              0               0     bitcoinagile
# 755              0               1     arbitragebot
# 756              0               7        wisewizzz
# 757              0               2     CashTechNews
# 758             66             263        cryptocom
# 759              0               0         BchPulse
# 760              0               1       CMCMarkets
# 761              0               0         ceuzcoin
# 762              0               2   cryptojubilado
# 763              0               0         BchPulse
# 764             63             198        cryptocom
# 765              0               0         BchPulse
# 766              0               0         ClankApp
# 767              0               0    CoignardDavid
# 768              0               0          ccexapp
# 769              0               0         BchPulse
#
#                            location  sentiment
# 0                  Montréal, Québec        0.0
# 1                                UK       -1.0
# 2       Vancouver, British Columbia        0.0
# 3                                         -4.0
# 4                                          0.0
# 5                             India        0.0
# 6                                          0.0
# 7                                          5.0
# 8                                          0.0
# 9                     New York, USA        0.0
# 10                                         0.0
# 11                    United States        0.0
# 12              North Carolina, USA       -1.0
# 13                                         1.0
# 14                  Los Angeles, CA        0.0
# 15                                         0.0
# 16   SHOP A4 IFEMELUNMA PLAZA, OKPU        1.0
# 17                     New York, NY        0.0
# 18              Islamabad, Pakistan        5.0
# 19                                         0.0
# 20                                         0.0
# 21                          Onchain        4.0
# 22                                         0.0
# 23                                         0.0
# 24                                         1.0
# 25            Dark Side Of The Moon        4.0
# 26                                         0.0
# 27                            Earth        0.0
# 28                  Tokyo-to, Japan        0.0
# 29                                         0.0
# ..                              ...        ...
# 740                 Tokyo-to, Japan        0.0
# 741                                        0.0
# 742                                        0.0
# 743                            Moon        0.0
# 744                                        0.0
# 745                                        0.0
# 746                       Venezuela        0.0
# 747                            Moon        0.0
# 748                 The Netherlands        0.0
# 749                          東京 渋谷区        0.0
# 750                                        0.0
# 751                Slatina, România        0.0
# 752                Slatina, România        0.0
# 753                         Estonia        0.0
# 754           Matter Doesn't Matter        2.0
# 755                 Los Angeles, CA        0.0
# 756                            Moon        4.0
# 757                    New York, NY       -4.0
# 758                                        0.0
# 759                                        0.0
# 760           Content is not advice        0.0
# 761                                        1.0
# 762                                        0.0
# 763                                        0.0
# 764                                        0.0
# 765                                        0.0
# 766                            Moon        0.0
# 767                                        0.0
# 768                 Tokyo-to, Japan        0.0
# 769                                        0.0
#
# [770 rows x 7 columns]

# %%
df.plot.line(x='created_at',y='retweet_count')

# %%
df.plot.line(x='created_at',y='sentiment')

# %%
df.to_csv('bitcoincash.csv')
